# %% [markdown]
# Questão 1. Aplique o teste Augmented Dickey Fuller (ADF) às bases de dados em anexo a esta atividade
# e indique se as mesmas são estacionárias ou não. Comente também se, ao analisar as séries
# graficamente, os resultados fazem sentido.

# %% [markdown]
# ***Questão 1 - BASE 1***

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

caminho_do_csv_1 = r"G:\Meu Drive\Drive dnasc\Especialização IFMG\Disciplinas\8 - Séries temporais\Lista 3 (08 de nov)\shampoo_sales - shampoo_sales.csv"

# Carregando os dados do CSV para um DataFrame
dados_serie_temporal_1 = pd.read_csv(caminho_do_csv_1)

# Criando um gráfico usando Matplotlib
plt.plot(dados_serie_temporal_1['Month'], dados_serie_temporal_1['Sales'])
plt.title('Série Temporal')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.show()

import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Função para realizar o teste ADF e imprimir os resultados
def teste_adf(serie, nome_serie):
    resultado_adf = adfuller(serie, autolag='AIC')
    print(f"Resultado do Teste ADF para {nome_serie}:")
    print(f"Estatística de Teste: {resultado_adf[0]}")
    print(f"Valor p: {resultado_adf[1]}")
    print("Valores Críticos:")
    for chave, valor in resultado_adf[4].items():
        print(f"   {chave}: {valor}")
        
        
# Substitua 'caminho/do/seu/arquivo.csv' pelo caminho real do seu arquivo CSV
caminho_do_csv_1 = r"G:\Meu Drive\Drive dnasc\Especialização IFMG\Disciplinas\8 - Séries temporais\Lista 3 (08 de nov)\shampoo_sales - shampoo_sales.csv"


# Carregando os dados do CSV para um DataFrame
dados_serie_temporal_1 = pd.read_csv(caminho_do_csv_1)

# Certifique-se de substituir 'sua_coluna_temporal' pela coluna específica de sua série temporal
sua_coluna_temporal_1 = dados_serie_temporal_1['Sales']

# Realizar o teste ADF
teste_adf(sua_coluna_temporal_1, 'Sales')
# Out:
# Resultado do Teste ADF para Sales:
# Estatística de Teste: 3.0601420836411806
# Valor p: 1.0
# Valores Críticos:
#    1%: -3.7238633119999998
#    5%: -2.98648896
#    10%: -2.6328004

# %% [markdown]
# ***Questão 1 - BASE 2***

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

caminho_do_csv_2 = r"G:\Meu Drive\Drive dnasc\Especialização IFMG\Disciplinas\8 - Séries temporais\Lista 3 (08 de nov)\airline-passengers - airline-passengers.csv"

# Carregando os dados do CSV para um DataFrame
dados_serie_temporal_2 = pd.read_csv(caminho_do_csv_2)

# Criando um gráfico usando Matplotlib
plt.plot(dados_serie_temporal_2['Month'], dados_serie_temporal_2['Passengers'])
plt.title('Série Temporal')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.show()

import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Função para realizar o teste ADF e imprimir os resultados
def teste_adf(serie, nome_serie):
    resultado_adf = adfuller(serie, autolag='AIC')
    print(f"Resultado do Teste ADF para {nome_serie}:")
    print(f"Estatística de Teste: {resultado_adf[0]}")
    print(f"Valor p: {resultado_adf[1]}")
    print("Valores Críticos:")
    for chave, valor in resultado_adf[4].items():
        print(f"   {chave}: {valor}")
        
        
# Substitua 'caminho/do/seu/arquivo.csv' pelo caminho real do seu arquivo CSV
caminho_do_csv_2 = r"G:\Meu Drive\Drive dnasc\Especialização IFMG\Disciplinas\8 - Séries temporais\Lista 3 (08 de nov)\airline-passengers - airline-passengers.csv"


# Carregando os dados do CSV para um DataFrame
dados_serie_temporal_2 = pd.read_csv(caminho_do_csv_2)

# Certifique-se de substituir 'sua_coluna_temporal' pela coluna específica de sua série temporal
sua_coluna_temporal_2 = dados_serie_temporal_2['Passengers']

# Realizar o teste ADF
teste_adf(sua_coluna_temporal_2, 'Passengers')
# Out:
# Resultado do Teste ADF para Passengers:
# Estatística de Teste: 0.8153688792060423
# Valor p: 0.9918802434376409
# Valores Críticos:
#    1%: -3.4816817173418295
#    5%: -2.8840418343195267
#    10%: -2.578770059171598

# %% [markdown]
# ***Questão 1 - BASE 3***

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

caminho_do_csv_3 = r"G:\Meu Drive\Drive dnasc\Especialização IFMG\Disciplinas\8 - Séries temporais\Lista 3 (08 de nov)\facebook-historical-stock-price.csv"

# Carregando os dados do CSV para um DataFrame
dados_serie_temporal_3 = pd.read_csv(caminho_do_csv_3)

# Criando um gráfico usando Matplotlib
plt.plot(dados_serie_temporal_3['Date'], dados_serie_temporal_3['Close'])
plt.title('Série Temporal')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.show()

import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Função para realizar o teste ADF e imprimir os resultados
def teste_adf(serie, nome_serie):
    resultado_adf = adfuller(serie, autolag='AIC')
    print(f"Resultado do Teste ADF para {nome_serie}:")
    print(f"Estatística de Teste: {resultado_adf[0]}")
    print(f"Valor p: {resultado_adf[1]}")
    print("Valores Críticos:")
    for chave, valor in resultado_adf[4].items():
        print(f"   {chave}: {valor}")
        
        
# Substitua 'caminho/do/seu/arquivo.csv' pelo caminho real do seu arquivo CSV
caminho_do_csv_3 = r"G:\Meu Drive\Drive dnasc\Especialização IFMG\Disciplinas\8 - Séries temporais\Lista 3 (08 de nov)\facebook-historical-stock-price.csv"


# Carregando os dados do CSV para um DataFrame
dados_serie_temporal_3 = pd.read_csv(caminho_do_csv_3)

# Certifique-se de substituir 'sua_coluna_temporal' pela coluna específica de sua série temporal
sua_coluna_temporal_3 = dados_serie_temporal_3['Close']

# Realizar o teste ADF
teste_adf(sua_coluna_temporal_3, 'Close')
# Out:
# Resultado do Teste ADF para Close:
# Estatística de Teste: -0.4481923518572887
# Valor p: 0.9017361242145868
# Valores Críticos:
#    1%: -3.4333923407704177
#    5%: -2.8628839944786275
#    10%: -2.567485476439311

# %% [markdown]
# ***Questão 1 - BASE 4***

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

caminho_do_csv_4 = r"G:\Meu Drive\Drive dnasc\Especialização IFMG\Disciplinas\8 - Séries temporais\Lista 3 (08 de nov)\Electric_Production.csv"

# Carregando os dados do CSV para um DataFrame
dados_serie_temporal_4 = pd.read_csv(caminho_do_csv_4)

# Criando um gráfico usando Matplotlib
plt.plot(dados_serie_temporal_4['DATE'], dados_serie_temporal_4['IPG2211A2N'])
plt.title('Série Temporal')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.show()

import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Função para realizar o teste ADF e imprimir os resultados
def teste_adf(serie, nome_serie):
    resultado_adf = adfuller(serie, autolag='AIC')
    print(f"Resultado do Teste ADF para {nome_serie}:")
    print(f"Estatística de Teste: {resultado_adf[0]}")
    print(f"Valor p: {resultado_adf[1]}")
    print("Valores Críticos:")
    for chave, valor in resultado_adf[4].items():
        print(f"   {chave}: {valor}")
        
        
# Substitua 'caminho/do/seu/arquivo.csv' pelo caminho real do seu arquivo CSV
caminho_do_csv_4 = r"G:\Meu Drive\Drive dnasc\Especialização IFMG\Disciplinas\8 - Séries temporais\Lista 3 (08 de nov)\Electric_Production.csv"


# Carregando os dados do CSV para um DataFrame
dados_serie_temporal_4 = pd.read_csv(caminho_do_csv_4)

# Certifique-se de substituir 'sua_coluna_temporal' pela coluna específica de sua série temporal
sua_coluna_temporal_4 = dados_serie_temporal_4['IPG2211A2N']

# Realizar o teste ADF
teste_adf(sua_coluna_temporal_4, 'IPG2211A2N')
# Out:
# Resultado do Teste ADF para IPG2211A2N:
# Estatística de Teste: -2.2569903500472455
# Valor p: 0.18621469116586759
# Valores Críticos:
#    1%: -3.4476305904172904
#    5%: -2.869155980820355
#    10%: -2.570827146203181

# %% [markdown]
# ***Questão 2***
# No notebook Aula_05b.ipynb vimos a aplicação de modelos ARCH/GARCH a uma série
# extraída do mercado financeiro. No entanto, o modelo GARCH(1,1) utilizado para previsão não
# pareceu estar bem ajustado, de acordo com o teste de Jarque-bera. Observe o conteúdo
# apresentado na Aula 05 e também as referências indicadas para encontrar uma nova
# configuração do modelo GARCH(p,q) que seja melhor ajustada, de acordo com o teste de
# Jarque-bera. Justifique os parâmetros escolhidos no modelo.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import yfinance as yf

# %% [markdown]
# ## Importação dos Dados
# Os dados usados são de valores do mercado financeiro obtidos do pacote yfinance

# %%
spy = yf.Ticker("SPY")
hist = spy.history(start = "2010-01-04", end = "2020-02-01")
df = pd.DataFrame(hist, columns=['Close'])
df.head()
# Out:
#                                Close
# Date
# 2010-01-04 00:00:00-05:00  87.483208
# 2010-01-05 00:00:00-05:00  87.714783
# 2010-01-06 00:00:00-05:00  87.776543
# 2010-01-07 00:00:00-05:00  88.147064
# 2010-01-08 00:00:00-05:00  88.440392

# %% [markdown]
# Uma transformação é aplicada para facilitar a análise da série. Ela consiste na diferenciação do log do valor de fechamento e obtenção do valor absoluto.

# %%
df['Retorno'] = np.pad(np.diff(np.log(df['Close'])) * 100, (1, 0), 'constant', constant_values=np.nan)
retorno_abs = df['Retorno'].abs()
retorno_abs.head()
# Out:
# Date
# 2010-01-04 00:00:00-05:00         NaN
# 2010-01-05 00:00:00-05:00    0.264358
# 2010-01-06 00:00:00-05:00    0.070385
# 2010-01-07 00:00:00-05:00    0.421231
# 2010-01-08 00:00:00-05:00    0.332218
# Name: Retorno, dtype: float64

# %% [markdown]
# A série é então exibida conforme abaixo.

# %%
plt.figure(figsize=(8,5))
plt.plot(retorno_abs)
plt.ylabel("Retorno absoluto")
plt.title('Retornos da S&P 500');

# %% [markdown]
# O teste de McLeod-Li verifica se a série possui algum efeito ARCH, avaliando as seguintes hipóteses:
#
# H₀: não parece haver efeito ARCH na série
#
# Hₐ: parece haver efeito ARCH na série

# %%
from scipy.stats import chi2

def mcleod_li_test(x, k, cutoff=0.01):
    n = len(x)
    x_sq = x ** 2
    x_sum = np.sum(x_sq)
    x_lag_sum = np.sum(x_sq[:-k])
    test_stat = n * (n + 2) * x_lag_sum / (x_sum ** 2)
    df = k
    p_value = 1 - chi2.cdf(test_stat, df)

    if p_value < cutoff:
      print('Parece haver efeito ARCH nos dados')
    else:
      print('Não parece haver efeito ARCH nos dados')

    return test_stat, p_value

# %% [markdown]
# Testando a série de S&P, temos a indicação de que ocorrem mudanças na variância, ou seja, existe a presença de um modelo ARCH

# %%
test_stat, p_value = mcleod_li_test(retorno_abs, 50)
print("Teste McLeod-Li: ", test_stat)
print("p-value: ", p_value)
# Out:
# Parece haver efeito ARCH nos dados
# Teste McLeod-Li:  2932.0634710801237
# p-value:  0.0

# %% [markdown]
# **Testando o melhor modelo GARCH**
# Para uma série temporal há, uma dificuldade em identificar a ordem de um modelo GARCH a fim
# de se ajustar a série temporal. Segundo Morettin e Toloi (2006) a recomendação inicial é
# que se use modelos de baixa ordem como (1,1), (1,2), (2,1) e (2,2) para que, posteriormente, se
# escolha o modelo baseado em critérios como AIC (Akaike) ou BIC (Bayesiano de Schwarz), valores da assimetria e curtose,
# verossimilhança, dentre outros.
# O critério AIC busca uma maior aproximação do modelo com a
# realidade, diferente do BIC que procura o ajuste perfeito.
# Para verificar estatisticamente qual modelo representa corretamente o
# processo gerador da série, farei a estimação desses modelos de (1,1) a (4,4) e escolher o que apresente o melhor critério AIC e BIC (quanto menores valores de AIC e BIC melhor será a qualidade de ajuste e parcimonia do modelo).

# %%
import pandas as pd
from arch import arch_model
from itertools import product

# Certifique-se de substituir 'sua_coluna_temporal' pela coluna específica de sua série temporal
sua_coluna_temporal = df['Retorno'].abs().dropna()

# Defina os valores máximos de p e q para a busca
p_values = range(1, 5)  # Substitua pelos valores que deseja testar para p
q_values = range(1, 5)  # Substitua pelos valores que deseja testar para q

# Listas para armazenar resultados de AIC e BIC
resultados_aic = []
resultados_bic = []

# Realizar busca sobre diferentes combinações de p e q
for p, q in product(p_values, q_values):
    try:
        modelo_garch = arch_model(sua_coluna_temporal, vol='Garch', p=p, q=q)
        resultado = modelo_garch.fit(disp='off')
        aic = resultado.aic
        bic = resultado.bic  # Adicione esta linha para obter o BIC
        resultados_aic.append((p, q, aic))
        resultados_bic.append((p, q, bic))
        print(f"Combinação (p, q): ({p}, {q}), AIC: {aic}, BIC: {bic}")
    except Exception as e:
        print(f"Falha para p={p}, q={q}: {e}")

# Verificar se há resultados antes de encontrar a combinação com menor AIC e BIC
if resultados_aic and resultados_bic:
    # Encontrar a combinação com menor AIC
    melhor_combinacao_aic = min(resultados_aic, key=lambda x: x[2])
    print(f"\nMelhor combinação (p, q) com menor AIC: {melhor_combinacao_aic}")

    # Encontrar a combinação com menor BIC
    melhor_combinacao_bic = min(resultados_bic, key=lambda x: x[2])
    print(f"Melhor combinação (p, q) com menor BIC: {melhor_combinacao_bic}")
else:
    print("\nNenhum resultado disponível. Verifique os parâmetros de busca.")
# Out:
# Combinação (p, q): (1, 1), AIC: 4353.852707218093, BIC: 4377.206080480321
# Combinação (p, q): (1, 2), AIC: 4355.852707794953, BIC: 4385.044424372739
# Combinação (p, q): (1, 3), AIC: 4357.773152411896, BIC: 4392.803212305239
# Combinação (p, q): (1, 4), AIC: 4359.773152544678, BIC: 4400.641555753577
# Combinação (p, q): (2, 1), AIC: 4355.74070488423, BIC: 4384.932421462016
# Combinação (p, q): (2, 2), AIC: 4355.305266826121, BIC: 4390.335326719463
# Combinação (p, q): (2, 3), AIC: 4357.429151803847, BIC: 4398.297555012747
# Combinação (p, q): (2, 4), AIC: 4358.044366786644, BIC: 4404.751113311101
# Combinação (p, q): (3, 1), AIC: 4357.740704182241, BIC: 4392.770764075583
# Combinação (p, q): (3, 2), AIC: 4357.305265969573, BIC: 4398.173669178473
# Combinação (p, q): (3, 3), AIC: 4359.4259646570035, BIC: 4406.132711181461
# Combinação (p, q): (3, 4), AIC: 4360.0444001093965, BIC: 4412.589489949411
# Combinação (p, q): (4, 1), AIC: 4359.313073156658, BIC: 4400.1814763655575
# ...

# %% [markdown]
# **Conclui-se que, mesmo utilizando o GARCH 1,1 de forma aleatória para se executar os testes de treinamento e previsão da volatilidade, verifica-se que ele é o mais indicado para o exercício.**

# %% [markdown]
# ## Ajuste e previsão de um modelo GARCH
#
# Para este exemplo, escolheremos inicialmente um modelo GARCH(1,1), utilizando 80% da base para treinamento e 20% para o testes de previsão da volatilidade

# %%
# !pip install arch

# %%
from sklearn.model_selection import train_test_split
from arch import arch_model

y_train, y_test = train_test_split(retorno_abs[1:], train_size= 0.8, shuffle=False)

garch_mod = arch_model(y_train, mean = "Zero",  vol='Garch', p=1, q=2, rescale=False)
res_garch = garch_mod.fit()
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 1113821636.1217976
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 3901.1740647661813
# Iteration:      3,   Func. Count:     20,   Neg. LLF: 2736.085633491237
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 2853.2819600139983
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 2411.310706759985
# Iteration:      6,   Func. Count:     39,   Neg. LLF: 2417.2525784393442
# Iteration:      7,   Func. Count:     45,   Neg. LLF: 2408.629292007553
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 2403.6977904402856
# Iteration:      9,   Func. Count:     56,   Neg. LLF: 2403.692839326007
# Iteration:     10,   Func. Count:     61,   Neg. LLF: 2403.69225694252
# Iteration:     11,   Func. Count:     66,   Neg. LLF: 2403.6922561389547
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2403.6922561389547
#             Iterations: 11
#             Function evaluations: 66
# ...

# %%
res_garch.summary
# Out:
# <bound method ARCHModelResult.summary of                        Zero Mean - GARCH Model Results
# ...
# Dep. Variable:                Retorno   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2403.69
# Distribution:                  Normal   AIC:                           4815.38
# Method:            Maximum Likelihood   BIC:                           4837.84
#                                         No. Observations:                 2028
# Date:                Wed, Nov 22 2023   Df Residuals:                     2028
# Time:                        19:01:52   Df Model:                            0
#                               Volatility Model
# ...
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# ...

# %% [markdown]
# A função summary exibe, dentre outras informações, os parâmetros estimados para o modelo. No caso deste GARCH(1,1), os parâmetros omega, alpha e beta se referem, respectivamente, à constante, o coeficiente do lag e o coeficiente da variância passada.

# %% [markdown]
# ### Previsão pelo modelo GARCH
# Exemplo de previsão para horizonte de 1 passo

# %%
yhat = res_garch.forecast(horizon = 1, reindex=True)

# %% [markdown]
# Validação do modelo a partir do método rolling forecasting

# %%
rolling_preds = []

for i in range(y_test.shape[0]):
    train = retorno_abs[1:-(y_test.shape[0]-i)]
    model = arch_model(train, p=1, q=2, rescale = False)
    model_fit = model.fit(disp='off')
    # One step ahead predictor
    pred = model_fit.forecast(horizon=1, reindex=True)
    rolling_preds.append(np.sqrt(pred.variance.values[-1,:][0]))

rolling_preds = pd.Series(rolling_preds, index=y_test.index)

# %% [markdown]
# Gráfico de previsão das volatilidades

# %%
fig,ax = plt.subplots(figsize=(10,4))
ax.spines[['top','right']].set_visible(False)
plt.plot(rolling_preds)
plt.title('S&P 500 Previsão de Volatilidade')
# Out:
# Text(0.5, 1.0, 'S&P 500 Previsão de Volatilidade')

# %%
fig,ax = plt.subplots(figsize=(10,4))
ax.plot(df['Retorno'][-y_test.shape[0]:])
ax.plot(y_test.index,rolling_preds)
ax.set_title("S&P 500 Previsões de Volatilidade")
ax.legend(['Retorno Observado', 'Previsão de Volatilidade'])
plt.show()

# %% [markdown]
# A figura acima indica um aumento nos valores de volatilidade exatamente nos terchos em que há uma maior variação nos valores máximos e mínimos da série. Isso indica que o modelo GARCH realizou algum ajuste sobre os dados.

# %% [markdown]
# ## Avaliação do modelo
#
# Ainda que visualmente tenhamos um indicativo de que o modelo está bem ajustado à série, é importante a utilização de métodos que possam avaliar o quão ajustado está o modelo, para eventualmente indicar melhorias nos parâmtetros escolhidos.
#
# Um teste que pode auxiliar nessa atividade é o teste de Jarque-Bera. Este teste verifica se os residuos estão normalmente distribuídos, o que sugere que o modelo aplicado está bem ajustado aos dados. Para o exemplo observado acima, o teste pode ser aplicado da seguinte maneira:

# %%
from scipy.stats import jarque_bera

def teste_ajuste_jarque_bera(model, cutoff=0.01):
  # Calcula os resíduos obtidos a partir dos dados de teste
  std_resid = model.resid / model.conditional_volatility

  # Aplica o teste de Jarque-Bera
  jb_test = jarque_bera(std_resid)

  test_statistic = jb_test[0]
  p_value = jb_test[1]

  if p_value < cutoff:
    print("Resíduos não estão normalmente distribuídos. Portanto, o modelo pode necessitar de mais ajustes.", )
  else:
    print("Resíduos estão normalmente distribuídos. Portanto, o modelo parece estar bem ajustado.", )

  return test_statistic, p_value

# %%
teste_ajuste_jarque_bera(res_garch)
# Out:
# Resíduos não estão normalmente distribuídos. Portanto, o modelo pode necessitar de mais ajustes.
# (1950.8653477608382, 0.0)

# %% [markdown]
# Para o exemplo realizado neste notebook, o teste inidica que podem ser necessários ajustes adicionais, sobretudo nos hiperparâmetros escolhidos.

# %% [markdown]
# **Após as verificações dos modelos GARCH de (1,1) a (4,4), constatei que o Jarque-Bera do GARCH 1,1 foi o que apresentou o menor valor**

# %% [markdown]
# ***Questão 3*** Aplique o modelo de Redes Neurais às mesmas bases de dados usadas na atividade anterior
# (Lista de Exercícios 3), realizando os mesmos experimentos citados nessa atividade. Em
# seguida, compare os resultados com o melhor modelo observado no experimento anterior.
# Discuta se houve um ganho na aplicação de um modelo de Aprendizado de Máquina ao
# problema de previsão de séries temporais. Avalie também se foram observadas dificuldades
# em alguns casos.

# %%
from math import sqrt

from keras.models import Sequential
from keras.layers import Dense
from matplotlib.pylab import rcParams
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_absolute_error

from numpy import array

import warnings
warnings.filterwarnings('ignore')

rcParams['figure.figsize'] = 15, 6

def split_sequence(sequence, n_lags):
 X, y = list(), list()
 for i in range(len(sequence)):

  end_ix = i + n_lags
  # Testa se a sequência chegou ao fim
  if end_ix > len(sequence)-1:
    break
  # cria os trechos x e y de cada amostra
  seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
  X.append(seq_x)
  y.append(seq_y)
 return array(X), array(y)

# %% [markdown]
# **Base 1**
# Preparando os dados da série temporal Electric Production, que foi importada no Exercício 1.

# %%
# número de lags
n_lags = 3

X, y = split_sequence(sua_coluna_temporal_1, n_lags)

for i in range(len(X)):
	print(X[i], y[i])
# Out:
# [266.  145.9 183.1] 119.3
# [145.9 183.1 119.3] 180.3
# [183.1 119.3 180.3] 168.5
# [119.3 180.3 168.5] 231.8
# [180.3 168.5 231.8] 224.5
# [168.5 231.8 224.5] 192.8
# [231.8 224.5 192.8] 122.9
# [224.5 192.8 122.9] 336.5
# [192.8 122.9 336.5] 185.9
# [122.9 336.5 185.9] 194.3
# [336.5 185.9 194.3] 149.5
# [185.9 194.3 149.5] 210.1
# [194.3 149.5 210.1] 273.3
# [149.5 210.1 273.3] 191.4
# [210.1 273.3 191.4] 287.0
# [273.3 191.4 287. ] 226.0
# [191.4 287.  226. ] 303.6
# [287.  226.  303.6] 289.9
# [226.  303.6 289.9] 421.6
# [303.6 289.9 421.6] 264.5
# [289.9 421.6 264.5] 342.3
# [421.6 264.5 342.3] 339.7
# [264.5 342.3 339.7] 440.4
# [342.3 339.7 440.4] 315.9
# [339.7 440.4 315.9] 439.3
# [440.4 315.9 439.3] 401.3
# [315.9 439.3 401.3] 437.4
# [439.3 401.3 437.4] 575.5
# [401.3 437.4 575.5] 407.6
# [437.4 575.5 407.6] 682.0
# [575.5 407.6 682. ] 475.3
# [407.6 682.  475.3] 581.3
# [682.  475.3 581.3] 646.9

# %% [markdown]
# Definindo a arquitetura MLP.

# %%
model = Sequential()
model.add(Dense(100, activation='relu', input_dim=n_lags))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# Treinando o modelo.

# %%
model.fit(X, y, epochs=2000, verbose=0)

# %% [markdown]
# Realizando uma previsão.

# %%
x_input = array([682., 475.3, 581.3])
x_input = x_input.reshape((1, n_lags))
yhat = model.predict(x_input, verbose=0)
print(yhat)
# Out:
# [[610.4631]]

# %% [markdown]
# Separando a baSeparando a base de dados em treinamento e teste (80/20), para realização da validação cruzada.

# %%
# 2. Separando a base de dados em treinamento e teste, na proporção de 80% para 20%.

size = int(len(X) * 0.80)
train, test = X[0:size], X[size:len(X)]

history = [np.double(x) for x in train]
predictions = []

# 3. Aplicando a previsão aos dados, usando validação cruzada.

for t in range(len(test)):
	model.fit(X, y, epochs=2000, verbose=0)
	x_input = test[t]
	x_input = x_input.reshape((1, n_lags))
	yhat = model.predict(x_input, verbose=0)
	predictions.append(yhat[0])
	obs = y[t+size]
	history.append(obs)
	print(f'teste={test[t]}, previsão={yhat[0]}, osbervado={obs}')
# Out:
# teste=[315.9 439.3 401.3], previsão=[440.31073], osbervado=437.4
# teste=[439.3 401.3 437.4], previsão=[504.22467], osbervado=575.5
# teste=[401.3 437.4 575.5], previsão=[376.61743], osbervado=407.6
# teste=[437.4 575.5 407.6], previsão=[583.56555], osbervado=682.0
# teste=[575.5 407.6 682. ], previsão=[472.7378], osbervado=475.3
# teste=[407.6 682.  475.3], previsão=[597.7787], osbervado=581.3
# teste=[682.  475.3 581.3], previsão=[611.85583], osbervado=646.9

# %% [markdown]
# Calculando as métricas de desempenho (MAE, RMSE e MAPE).

# %%
# 4. Medindo o desempenho do modelo a partir das métricas: MAE, RMSE e MAPE

mae = mean_absolute_error(history[size:], predictions)
print('Test MAE: %.3f' % mae)

rmse = sqrt(mean_squared_error(history[size:], predictions))
print('Test RMSE: %.3f' % rmse)

mape = mean_absolute_percentage_error(history[size:], predictions)
print('Test MAPE: %.3f' % mape)
# Out:
# Test MAE: 36.813
# Test RMSE: 49.633
# Test MAPE: 0.063

# %%
train_values = []
for i in range(len(train)):
    train_values.append(train[i][0])

# %%
test_values = []
for i in range(len(X) - size):
    test_values.append(test[i][0])

# %%
plt.title("Shampoo Sales")
plt.plot(test_values, label='Test')
plt.plot(predictions, color='red', label='Sales')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Plotando dados de treinamento, de teste e valores da previsão.

# %%
# 5 Ilustrando graficamente o desempenho do modelo.

fig, ax = plt.subplots()

ax.plot(sua_coluna_temporal_1.index[0:size], train_values, 'g-.', label='Train')
ax.plot(sua_coluna_temporal_1.index[size:len(X)], test_values, 'b-', label='Test')
ax.plot(sua_coluna_temporal_1.index[size:len(X)], predictions, 'r--', label='Predicted')
ax.set_xlabel('Month')
ax.set_ylabel('# Sales')
ax.axvspan(26, 32, color='#808080', alpha=0.2) # zona cinza
ax.legend(loc='best')
plt.title("Shampoo Sales")
plt.xticks(np.arange(0, 36, 2), [1901, 'mar', 'mai', 'jul', 'sep', 'nov', 1902, 'mar', 'mai', 'jul', 'sep', 'nov', 1903, 'mar', 'mai', 'jul', 'sep', 'nov'])

fig.autofmt_xdate()
plt.tight_layout()

# %% [markdown]
# Nos experimentos realizados com esta base de dados na lista de exercícios anterior, o modelo que apresentou melhor desempenho, considerando as métricas utilizadas (MAE, RMSE e MAPE), foi o modelo ARIMA.

# %% [markdown]
# **Base 2**
# Preparando os dados, importados no Exercício 1.

# %%
# número de lags
n_lags = 3

X, y = split_sequence(sua_coluna_temporal_2, n_lags)

for i in range(len(X)):
	print(X[i], y[i])
# Out:
# [112 118 132] 129
# [118 132 129] 121
# [132 129 121] 135
# [129 121 135] 148
# [121 135 148] 148
# [135 148 148] 136
# [148 148 136] 119
# [148 136 119] 104
# [136 119 104] 118
# [119 104 118] 115
# [104 118 115] 126
# [118 115 126] 141
# [115 126 141] 135
# [126 141 135] 125
# [141 135 125] 149
# [135 125 149] 170
# [125 149 170] 170
# [149 170 170] 158
# [170 170 158] 133
# [170 158 133] 114
# [158 133 114] 140
# [133 114 140] 145
# [114 140 145] 150
# [140 145 150] 178
# [145 150 178] 163
# [150 178 163] 172
# [178 163 172] 178
# [163 172 178] 199
# [172 178 199] 199
# [178 199 199] 184
# [199 199 184] 162
# [199 184 162] 146
# [184 162 146] 166
# [162 146 166] 171
# [146 166 171] 180
# [166 171 180] 193
# [171 180 193] 181
# [180 193 181] 183
# [193 181 183] 218
# [181 183 218] 230
# [183 218 230] 242
# [218 230 242] 209
# [230 242 209] 191
# [242 209 191] 172
# [209 191 172] 194
# [191 172 194] 196
# [172 194 196] 196
# [194 196 196] 236
# [196 196 236] 235
# [196 236 235] 229
# ...

# %% [markdown]
# Definindo a arquitetura MLP.

# %%
model = Sequential()
model.add(Dense(100, activation='relu', input_dim=n_lags))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# Treinando o modelo.

# %%
model.fit(X, y, epochs=2000, verbose=0)

# %% [markdown]
# Realizando a previsão.

# %%
x_input = array([508, 461, 390])
x_input = x_input.reshape((1, n_lags))
yhat = model.predict(x_input, verbose=0)
print(yhat)
# Out:
# [[377.7875]]

# %% [markdown]
# Separando a base de dados em treinamento e teste (80/20), para realização da validação cruzada.

# %%
# 2. Separando a base de dados em treinamento e teste, na proporção de 80% para 20%.

size = int(len(X) * 0.80)
train, test = X[0:size], X[size:len(X)]

history = [np.double(x) for x in train]
predictions = []

# 3. Aplicando a previsão aos dados, usando validação cruzada.

for t in range(len(test)):
	model.fit(X, y, epochs=2000, verbose=0)
	x_input = test[t]
	x_input = x_input.reshape((1, n_lags))
	yhat = model.predict(x_input, verbose=0)
	predictions.append(yhat[0])
	obs = y[t+size]
	history.append(obs)
	print(f'teste={test[t]}, previsão={yhat[0]}, osbervado={obs}')
# Out:
# teste=[363 435 491], previsão=[469.56195], osbervado=505
# teste=[435 491 505], previsão=[469.09265], osbervado=404
# teste=[491 505 404], previsão=[335.89896], osbervado=359
# teste=[505 404 359], previsão=[300.80093], osbervado=310
# teste=[404 359 310], previsão=[315.79745], osbervado=337
# teste=[359 310 337], previsão=[357.6106], osbervado=360
# teste=[310 337 360], previsão=[353.90295], osbervado=342
# teste=[337 360 342], previsão=[364.26028], osbervado=406
# teste=[360 342 406], previsão=[403.48282], osbervado=396
# teste=[342 406 396], previsão=[374.39786], osbervado=420
# teste=[406 396 420], previsão=[485.12067], osbervado=472
# teste=[396 420 472], previsão=[515.6707], osbervado=548
# teste=[420 472 548], previsão=[551.7389], osbervado=559
# teste=[472 548 559], previsão=[492.3744], osbervado=463
# teste=[548 559 463], previsão=[398.48465], osbervado=407
# teste=[559 463 407], previsão=[370.42944], osbervado=362
# teste=[463 407 362], previsão=[357.9791], osbervado=405
# ...

# %% [markdown]
# Calculando as métricas de desempenho do modelo (MAE, RMSE e MAPE).

# %%
# 4. Medindo o desempenho do modelo a partir das métricas: MAE, RMSE e MAPE

mae = mean_absolute_error(history[size:], predictions)
print('Test MAE: %.3f' % mae)

rmse = sqrt(mean_squared_error(history[size:], predictions))
print('Test RMSE: %.3f' % rmse)

mape = mean_absolute_percentage_error(history[size:], predictions)
print('Test MAPE: %.3f' % mape)
# Out:
# Test MAE: 21.648
# Test RMSE: 29.094
# Test MAPE: 0.049

# %%
train_values = []
for i in range(len(train)):
    train_values.append(train[i][0])

test_values = []
for i in range(len(X) - size):
    test_values.append(test[i][0])

# %% [markdown]
# Plotando dados de teste e valores da previsão.

# %%
plt.title("Airline Passengers")
plt.plot(test_values, label='Test')
plt.plot(predictions, color='red', label='Prediction')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Plotando o resultado final, com dados de treinamento, dados de teste e valores das previsões.

# %%
# 5 Ilustrando graficamente o desempenho do modelo.

fig, ax = plt.subplots()

ax.plot(sua_coluna_temporal_2.index[0:size], train_values, 'g-.', label='Train')
ax.plot(sua_coluna_temporal_2.index[size:len(X)], test_values, 'b-', label='Test')
ax.plot(sua_coluna_temporal_2.index[size:len(X)], predictions, 'r--', label='Predicted')
ax.set_xlabel('Year')
ax.set_ylabel('Production') 
ax.legend(loc='best')
plt.title("Airline Passengers")

fig.autofmt_xdate()
plt.tight_layout()

# %% [markdown]
# Nos experimentos realizados com esta base, na lista de exercícios anterior, o modelo que apresentou melhor desempenho, considerando as métricas utilizadas (MAE, RMSE e MAPE), foi o modelo ARIMA

# %% [markdown]
# Carlos, não fiz a base do Facebook pois os dados são muito densos e meu PC não conseguiu finalizar a tempo.

# %% [markdown]
# **Base 4**
# Preparando os dados da série temporal Electric Production, que foi importada no Exercício 1.

# %%
# número de lags
n_lags = 3

X, y = split_sequence(sua_coluna_temporal_4, n_lags)

for i in range(len(X)):
	print(X[i], y[i])
# Out:
# [72.5052 70.672  62.4502] 57.4714
# [70.672  62.4502 57.4714] 55.3151
# [62.4502 57.4714 55.3151] 58.0904
# [57.4714 55.3151 58.0904] 62.6202
# [55.3151 58.0904 62.6202] 63.2485
# [58.0904 62.6202 63.2485] 60.5846
# [62.6202 63.2485 60.5846] 56.3154
# [63.2485 60.5846 56.3154] 58.0005
# [60.5846 56.3154 58.0005] 68.7145
# [56.3154 58.0005 68.7145] 73.3057
# [58.0005 68.7145 73.3057] 67.9869
# [68.7145 73.3057 67.9869] 62.2221
# [73.3057 67.9869 62.2221] 57.0329
# [67.9869 62.2221 57.0329] 55.8137
# [62.2221 57.0329 55.8137] 59.9005
# [57.0329 55.8137 59.9005] 65.7655
# [55.8137 59.9005 65.7655] 64.4816
# [59.9005 65.7655 64.4816] 61.0005
# [65.7655 64.4816 61.0005] 57.5322
# [64.4816 61.0005 57.5322] 59.3417
# [61.0005 57.5322 59.3417] 68.1354
# [57.5322 59.3417 68.1354] 73.8152
# [59.3417 68.1354 73.8152] 70.062
# [68.1354 73.8152 70.062 ] 65.61
# [73.8152 70.062  65.61  ] 60.1586
# [70.062  65.61   60.1586] 58.8734
# [65.61   60.1586 58.8734] 63.8918
# ...

# %% [markdown]
# Definindo a arquitetura MLP.

# %%
model = Sequential()
model.add(Dense(100, activation='relu', input_dim=n_lags))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# Treinando o modelo.

# %%
model.fit(X, y, epochs=2000, verbose=0)

# %% [markdown]
# Realizando uma previsão.

# %%
x_input = array([93.6137, 97.3359, 114.7212])
print(f'{x_input}')
x_input = x_input.reshape((1, n_lags))
print(f'{x_input}')
yhat = model.predict(x_input, verbose=0)
print(yhat)
# Out:
# [ 93.6137  97.3359 114.7212]
# [[ 93.6137  97.3359 114.7212]]
# [[121.85062]]

# %% [markdown]
# Separando a base de dados em treinamento e teste (80/20), para realização da validação cruzada.

# %%
# 2. Separando a base de dados em treinamento e teste, na proporção de 80% para 20%.

size = int(len(X) * 0.80)
train, test = X[0:size], X[size:len(X)]

history = [np.double(x) for x in train]
predictions = []

# 3. Aplicando a previsão aos dados, usando validação cruzada.

for t in range(len(test)):
	model.fit(X, y, epochs=2000, verbose=0)
	x_input = test[t]
	x_input = x_input.reshape((1, n_lags))
	yhat = model.predict(x_input, verbose=0)
	predictions.append(yhat[0])
	obs = y[t+size]
	history.append(obs)
	print(f'teste={test[t]}, previsão={yhat[0]}, osbervado={obs}')
# Out:
# teste=[ 89.3583  90.0698 102.8204], previsão=[111.60157], osbervado=114.7068
# teste=[ 90.0698 102.8204 114.7068], previsão=[110.532936], osbervado=113.5958
# teste=[102.8204 114.7068 113.5958], previsão=[100.495476], osbervado=99.4712
# teste=[114.7068 113.5958  99.4712], previsão=[93.76021], osbervado=90.3566
# teste=[113.5958  99.4712  90.3566], previsão=[89.78127], osbervado=93.8095
# teste=[99.4712 90.3566 93.8095], previsão=[107.15395], osbervado=107.3312
# teste=[ 90.3566  93.8095 107.3312], previsão=[113.98732], osbervado=111.9646
# teste=[ 93.8095 107.3312 111.9646], previsão=[105.06975], osbervado=103.3679
# teste=[107.3312 111.9646 103.3679], previsão=[95.29898], osbervado=93.5772
# teste=[111.9646 103.3679  93.5772], previsão=[90.84252], osbervado=87.5566
# teste=[103.3679  93.5772  87.5566], previsão=[87.2128], osbervado=92.7603
# teste=[93.5772 87.5566 92.7603], previsão=[103.22023], osbervado=101.14
# ...

# %% [markdown]
# Calculando as métricas de desempenho (MAE, RMSE e MAPE).

# %%
# 4. Medindo o desempenho do modelo a partir das métricas: MAE, RMSE e MAPE

mae = mean_absolute_error(history[size:], predictions)
print('Test MAE: %.3f' % mae)

rmse = sqrt(mean_squared_error(history[size:], predictions))
print('Test RMSE: %.3f' % rmse)

mape = mean_absolute_percentage_error(history[size:], predictions)
print('Test MAPE: %.3f' % mape)
# Out:
# Test MAE: 3.806
# Test RMSE: 4.949
# Test MAPE: 0.037

# %%
train_values = []
for i in range(len(train)):
    train_values.append(train[i][0])
test_values = []
for i in range(len(X) - size):
    test_values.append(test[i][0])

# %%
plt.title("Electric Production")
plt.plot(test_values, label='Test')
plt.plot(predictions, color='red', label='Prediction')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Plotando os dados de treinamento, de teste e valores da previsão.

# %%
# 5 Ilustrando graficamente o desempenho do modelo.

fig, ax = plt.subplots()

ax.plot(sua_coluna_temporal_4.index[0:size], train_values, 'g-.', label='Train')
ax.plot(sua_coluna_temporal_4.index[size:len(X)], test_values, 'b-', label='Test')
ax.plot(sua_coluna_temporal_4.index[size:len(X)], predictions, 'r--', label='Predicted')
ax.set_xlabel('Year')
ax.set_ylabel('Production')
ax.axvspan(315, 393, color='#808080', alpha=0.2) # zona cinza
ax.legend(loc='best')
plt.title("Electric Production")
plt.xticks(np.arange(0, 396, 33), [1985, 1988, 1991, 1994, 1997, 2000, 2003, 2006, 2009, 2012, 2015, 2018])

fig.autofmt_xdate()
plt.tight_layout()

# %% [markdown]
# Nos experimentos realizados com esta base, na lista de exercícios anterior, o modelo que apresentou melhor desempenho, considerando as métricas utilizadas (MAE, RMSE e MAPE), foi o modelo ARIMA.
